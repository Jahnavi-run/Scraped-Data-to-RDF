# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahnavi-run/Scraped-Data-to-RDF/blob/main/imdb_scraper_topmovies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMDB Scraper
# **Notebook to scrape movies from IMDB, particularly this page: https://m.imdb.com/chart/top/. The script gets 100 movies.**

# %% [markdown]
# ## Install the required Packages

# %%
# !pip install scrapy crochet --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 700.9 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.1 MB/s eta 0:00:00

# %% [markdown]
# ## Importing the required packages.

# %%
import scrapy
from scrapy.crawler import CrawlerRunner
from scrapy.utils.log import configure_logging
from crochet import setup, wait_for
import pandas as pd
setup()

# %% [markdown]
# ## Scraping using the CSS classes.

# %%
class IMDBSpider(scrapy.Spider):
    name = 'imdb_top250_detailed'
    allowed_domains = ['imdb.com']
    start_urls = ['https://www.imdb.com/chart/top/']

    custom_settings = {
        'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'ROBOTSTXT_OBEY': True,
        'CONCURRENT_REQUESTS': 10,
        'FEED_FORMAT': 'csv',
        'FEED_URI': 'imdb_top250_detailed.csv',
    }

    def parse(self, response):
        movies = set(response.css('li.ipc-metadata-list-summary-item a::attr(href)').getall())
        for movie in movies:
            yield response.follow(movie, self.parse_movie)

    def parse_movie(self, response):
        yield {
            'movie_title': response.css('span.hero__primary-text::text').get(),
            'director': list(set(response.css('.ipc-metadata-list__item:contains("Director") .ipc-inline-list__item a::text').getall())),
            'synopsis': response.css("span.sc-42125d72-0.gKbnVu::text").get(),
            'actors': list(set(response.css('.ipc-metadata-list__item:contains("Stars") .ipc-inline-list__item a::text').getall())),
            'genre': response.css("div.ipc-chip-list__scroller span::text").getall(),
            'rating': response.css('span.sc-d541859f-1.imUuxf::text').get(),
        }

# %%
from twisted.internet import defer

# Configure logging to suppress verbose output
configure_logging({'LOG_FORMAT': '%(levelname)s: %(message)s'})

# Initialize the crawler runner
runner = CrawlerRunner()

# Store scraped data
scraped_items = []

@wait_for(600)  # Timeout after 600 seconds
@defer.inlineCallbacks
def crawl():
    yield runner.crawl(IMDBSpider, cb_kwargs={'items': scraped_items})

crawl()
# Out:
# INFO:scrapy.addons:Enabled addons:
# []
# 2025-03-25 07:21:28 [scrapy.addons] INFO: Enabled addons:
# []
# INFO:scrapy.extensions.telnet:Telnet Password: 7937d34a14d475f0
# 2025-03-25 07:21:28 [scrapy.extensions.telnet] INFO: Telnet Password: 7937d34a14d475f0
# INFO:scrapy.middleware:Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-03-25 07:21:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# INFO:scrapy.crawler:Overridden settings:
# {'CONCURRENT_REQUESTS': 10,
#  'ROBOTSTXT_OBEY': True,
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
# 2025-03-25 07:21:28 [scrapy.crawler] INFO: Overridden settings:
# {'CONCURRENT_REQUESTS': 10,
#  'ROBOTSTXT_OBEY': True,
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
# INFO:scrapy.middleware:Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-03-25 07:21:29 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# INFO:scrapy.middleware:Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-03-25 07:21:29 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# INFO:scrapy.middleware:Enabled item pipelines:
# []
# 2025-03-25 07:21:29 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# INFO:scrapy.core.engine:Spider opened
# 2025-03-25 07:21:29 [scrapy.core.engine] INFO: Spider opened
# INFO:scrapy.extensions.logstats:Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-03-25 07:21:29 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# INFO:scrapy.extensions.telnet:Telnet console listening on 127.0.0.1:6023
# 2025-03-25 07:21:29 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/robots.txt> (referer: None)
# 2025-03-25 07:21:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/robots.txt> (referer: None)
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): publicsuffix.org:443
# 2025-03-25 07:21:32 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): publicsuffix.org:443
# DEBUG:urllib3.connectionpool:https://publicsuffix.org:443 "GET /list/public_suffix_list.dat HTTP/1.1" 200 86823
# 2025-03-25 07:21:32 [urllib3.connectionpool] DEBUG: https://publicsuffix.org:443 "GET /list/public_suffix_list.dat HTTP/1.1" 200 86823
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/chart/top/> (referer: None)
# 2025-03-25 07:21:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/chart/top/> (referer: None)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0137523/?ref_=chttp_i_13> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0137523/?ref_=chttp_i_13> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0108052/?ref_=chttp_i_7> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0108052/?ref_=chttp_i_7> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0137523/?ref_=chttp_i_13>
# {'movie_title': 'Fight Club', 'director': ['David Fincher'], 'synopsis': 'An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.', 'actors': ['Edward Norton', 'Brad Pitt', 'Meat Loaf'], 'genre': ['Psychological Drama', 'Psychological Thriller', 'Workplace Drama', 'Crime', 'Drama', 'Thriller'], 'rating': '8.8'}
# 2025-03-25 07:21:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0137523/?ref_=chttp_i_13>
# {'movie_title': 'Fight Club', 'director': ['David Fincher'], 'synopsis': 'An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.', 'actors': ['Edward Norton', 'Brad Pitt', 'Meat Loaf'], 'genre': ['Psychological Drama', 'Psychological Thriller', 'Workplace Drama', 'Crime', 'Drama', 'Thriller'], 'rating': '8.8'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0108052/?ref_=chttp_i_7>
# {'movie_title': "Schindler's List", 'director': ['Steven Spielberg'], 'synopsis': 'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.', 'actors': ['Liam Neeson', 'Ben Kingsley', 'Ralph Fiennes'], 'genre': ['Docudrama', 'Epic', 'Historical Epic', 'Period Drama', 'Prison Drama', 'Tragedy', 'Biography', 'Drama', 'History'], 'rating': '9.0'}
# 2025-03-25 07:21:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0108052/?ref_=chttp_i_7>
# {'movie_title': "Schindler's List", 'director': ['Steven Spielberg'], 'synopsis': 'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.', 'actors': ['Liam Neeson', 'Ben Kingsley', 'Ralph Fiennes'], 'genre': ['Docudrama', 'Epic', 'Historical Epic', 'Period Drama', 'Prison Drama', 'Tragedy', 'Biography', 'Drama', 'History'], 'rating': '9.0'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0050083/?ref_=chttp_i_5> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0050083/?ref_=chttp_i_5> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0137523/?ref_=chttp_t_13> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0137523/?ref_=chttp_t_13> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0133093/?ref_=chttp_t_16> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0133093/?ref_=chttp_t_16> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0167261/?ref_=chttp_t_12> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0167261/?ref_=chttp_t_12> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0050083/?ref_=chttp_i_5>
# {'movie_title': '12 Angry Men', 'director': ['Sidney Lumet'], 'synopsis': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.', 'actors': ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam'], 'genre': ['Legal Drama', 'Psychological Drama', 'Crime', 'Drama'], 'rating': '9.0'}
# 2025-03-25 07:21:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0050083/?ref_=chttp_i_5>
# {'movie_title': '12 Angry Men', 'director': ['Sidney Lumet'], 'synopsis': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.', 'actors': ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam'], 'genre': ['Legal Drama', 'Psychological Drama', 'Crime', 'Drama'], 'rating': '9.0'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0137523/?ref_=chttp_t_13>
# {'movie_title': 'Fight Club', 'director': ['David Fincher'], 'synopsis': 'An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.', 'actors': ['Edward Norton', 'Brad Pitt', 'Meat Loaf'], 'genre': ['Psychological Drama', 'Psychological Thriller', 'Workplace Drama', 'Crime', 'Drama', 'Thriller'], 'rating': '8.8'}
# 2025-03-25 07:21:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0137523/?ref_=chttp_t_13>
# {'movie_title': 'Fight Club', 'director': ['David Fincher'], 'synopsis': 'An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.', 'actors': ['Edward Norton', 'Brad Pitt', 'Meat Loaf'], 'genre': ['Psychological Drama', 'Psychological Thriller', 'Workplace Drama', 'Crime', 'Drama', 'Thriller'], 'rating': '8.8'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0133093/?ref_=chttp_t_16>
# {'movie_title': 'The Matrix', 'director': ['Lana Wachowski', 'Lilly Wachowski'], 'synopsis': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.', 'actors': ['Laurence Fishburne', 'Keanu Reeves', 'Carrie-Anne Moss'], 'genre': ['Action Epic', 'Artificial Intelligence', 'Cyberpunk', 'Dystopian Sci-Fi', 'Gun Fu', 'Martial Arts', 'Sci-Fi Epic', 'Action', 'Sci-Fi'], 'rating': '8.7'}
# 2025-03-25 07:21:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0133093/?ref_=chttp_t_16>
# {'movie_title': 'The Matrix', 'director': ['Lana Wachowski', 'Lilly Wachowski'], 'synopsis': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.', 'actors': ['Laurence Fishburne', 'Keanu Reeves', 'Carrie-Anne Moss'], 'genre': ['Action Epic', 'Artificial Intelligence', 'Cyberpunk', 'Dystopian Sci-Fi', 'Gun Fu', 'Martial Arts', 'Sci-Fi Epic', 'Action', 'Sci-Fi'], 'rating': '8.7'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0167261/?ref_=chttp_t_12>
# {'movie_title': 'The Lord of the Rings: The Two Towers', 'director': ['Peter Jackson'], 'synopsis': "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.", 'actors': ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Quest', 'Sword & Sorcery', 'Adventure', 'Drama', 'Fantasy'], 'rating': '8.8'}
# 2025-03-25 07:21:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0167261/?ref_=chttp_t_12>
# {'movie_title': 'The Lord of the Rings: The Two Towers', 'director': ['Peter Jackson'], 'synopsis': "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.", 'actors': ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Quest', 'Sword & Sorcery', 'Adventure', 'Drama', 'Fantasy'], 'rating': '8.8'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0167261/?ref_=chttp_i_12> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0167261/?ref_=chttp_i_12> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0047478/?ref_=chttp_t_22> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0047478/?ref_=chttp_t_22> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0167261/?ref_=chttp_i_12>
# {'movie_title': 'The Lord of the Rings: The Two Towers', 'director': ['Peter Jackson'], 'synopsis': "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.", 'actors': ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Quest', 'Sword & Sorcery', 'Adventure', 'Drama', 'Fantasy'], 'rating': '8.8'}
# 2025-03-25 07:21:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0167261/?ref_=chttp_i_12>
# {'movie_title': 'The Lord of the Rings: The Two Towers', 'director': ['Peter Jackson'], 'synopsis': "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.", 'actors': ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Quest', 'Sword & Sorcery', 'Adventure', 'Drama', 'Fantasy'], 'rating': '8.8'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0047478/?ref_=chttp_t_22>
# {'movie_title': 'Seven Samurai', 'director': ['Akira Kurosawa'], 'synopsis': 'Farmers from a village exploited by bandits hire a veteran samurai for protection, and he gathers six other samurai to join him.', 'actors': ['Keiko Tsushima', 'Toshirô Mifune', 'Takashi Shimura'], 'genre': ['Action Epic', 'Epic', 'Period Drama', 'Samurai', 'Action', 'Drama'], 'rating': '8.6'}
# 2025-03-25 07:21:34 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0047478/?ref_=chttp_t_22>
# {'movie_title': 'Seven Samurai', 'director': ['Akira Kurosawa'], 'synopsis': 'Farmers from a village exploited by bandits hire a veteran samurai for protection, and he gathers six other samurai to join him.', 'actors': ['Keiko Tsushima', 'Toshirô Mifune', 'Takashi Shimura'], 'genre': ['Action Epic', 'Epic', 'Period Drama', 'Samurai', 'Action', 'Drama'], 'rating': '8.6'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0047478/?ref_=chttp_i_22> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0047478/?ref_=chttp_i_22> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0047478/?ref_=chttp_i_22>
# {'movie_title': 'Seven Samurai', 'director': ['Akira Kurosawa'], 'synopsis': 'Farmers from a village exploited by bandits hire a veteran samurai for protection, and he gathers six other samurai to join him.', 'actors': ['Keiko Tsushima', 'Toshirô Mifune', 'Takashi Shimura'], 'genre': ['Action Epic', 'Epic', 'Period Drama', 'Samurai', 'Action', 'Drama'], 'rating': '8.6'}
# 2025-03-25 07:21:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0047478/?ref_=chttp_i_22>
# {'movie_title': 'Seven Samurai', 'director': ['Akira Kurosawa'], 'synopsis': 'Farmers from a village exploited by bandits hire a veteran samurai for protection, and he gathers six other samurai to join him.', 'actors': ['Keiko Tsushima', 'Toshirô Mifune', 'Takashi Shimura'], 'genre': ['Action Epic', 'Epic', 'Period Drama', 'Samurai', 'Action', 'Drama'], 'rating': '8.6'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0317248/?ref_=chttp_t_25> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0317248/?ref_=chttp_t_25> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0111161/?ref_=chttp_i_1> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0111161/?ref_=chttp_i_1> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0317248/?ref_=chttp_t_25>
# {'movie_title': 'City of God', 'director': ['Kátia Lund', 'Fernando Meirelles'], 'synopsis': "In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.", 'actors': ['Alexandre Rodrigues', 'Matheus Nachtergaele', 'Leandro Firmino'], 'genre': ['Caper', 'Coming-of-Age', 'Gangster', 'Crime', 'Drama'], 'rating': '8.6'}
# 2025-03-25 07:21:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0317248/?ref_=chttp_t_25>
# {'movie_title': 'City of God', 'director': ['Kátia Lund', 'Fernando Meirelles'], 'synopsis': "In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.", 'actors': ['Alexandre Rodrigues', 'Matheus Nachtergaele', 'Leandro Firmino'], 'genre': ['Caper', 'Coming-of-Age', 'Gangster', 'Crime', 'Drama'], 'rating': '8.6'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0111161/?ref_=chttp_i_1>
# {'movie_title': 'The Shawshank Redemption', 'director': ['Frank Darabont'], 'synopsis': 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.', 'actors': ['Tim Robbins', 'Bob Gunton', 'Morgan Freeman'], 'genre': ['Epic', 'Period Drama', 'Prison Drama', 'Drama'], 'rating': '9.3'}
# 2025-03-25 07:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0111161/?ref_=chttp_i_1>
# {'movie_title': 'The Shawshank Redemption', 'director': ['Frank Darabont'], 'synopsis': 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.', 'actors': ['Tim Robbins', 'Bob Gunton', 'Morgan Freeman'], 'genre': ['Epic', 'Period Drama', 'Prison Drama', 'Drama'], 'rating': '9.3'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0068646/?ref_=chttp_t_2> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0068646/?ref_=chttp_t_2> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0120737/?ref_=chttp_t_9> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0120737/?ref_=chttp_t_9> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0068646/?ref_=chttp_t_2>
# {'movie_title': 'The Godfather', 'director': ['Francis Ford Coppola'], 'synopsis': 'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.', 'actors': ['Al Pacino', 'James Caan', 'Marlon Brando'], 'genre': ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama'], 'rating': '9.2'}
# 2025-03-25 07:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0068646/?ref_=chttp_t_2>
# {'movie_title': 'The Godfather', 'director': ['Francis Ford Coppola'], 'synopsis': 'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.', 'actors': ['Al Pacino', 'James Caan', 'Marlon Brando'], 'genre': ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama'], 'rating': '9.2'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0120737/?ref_=chttp_t_9>
# {'movie_title': 'The Lord of the Rings: The Fellowship of the Ring', 'director': ['Peter Jackson'], 'synopsis': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.', 'actors': ['Elijah Wood', 'Orlando Bloom', 'Ian McKellen'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Quest', 'Sword & Sorcery', 'Adventure', 'Drama', 'Fantasy'], 'rating': '8.9'}
# 2025-03-25 07:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0120737/?ref_=chttp_t_9>
# {'movie_title': 'The Lord of the Rings: The Fellowship of the Ring', 'director': ['Peter Jackson'], 'synopsis': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.', 'actors': ['Elijah Wood', 'Orlando Bloom', 'Ian McKellen'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Quest', 'Sword & Sorcery', 'Adventure', 'Drama', 'Fantasy'], 'rating': '8.9'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0099685/?ref_=chttp_t_17> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0099685/?ref_=chttp_t_17> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0110912/?ref_=chttp_t_8> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0110912/?ref_=chttp_t_8> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0099685/?ref_=chttp_t_17>
# {'movie_title': 'Goodfellas', 'director': ['Martin Scorsese'], 'synopsis': 'The story of Henry Hill and his life in the mafia, covering his relationship with his wife Karen and his mob partners Jimmy Conway and Tommy DeVito.', 'actors': ['Robert De Niro', 'Joe Pesci', 'Ray Liotta'], 'genre': ['Docudrama', 'Gangster', 'True Crime', 'Biography', 'Crime', 'Drama'], 'rating': '8.7'}
# 2025-03-25 07:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0099685/?ref_=chttp_t_17>
# {'movie_title': 'Goodfellas', 'director': ['Martin Scorsese'], 'synopsis': 'The story of Henry Hill and his life in the mafia, covering his relationship with his wife Karen and his mob partners Jimmy Conway and Tommy DeVito.', 'actors': ['Robert De Niro', 'Joe Pesci', 'Ray Liotta'], 'genre': ['Docudrama', 'Gangster', 'True Crime', 'Biography', 'Crime', 'Drama'], 'rating': '8.7'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0110912/?ref_=chttp_t_8>
# {'movie_title': 'Pulp Fiction', 'director': ['Quentin Tarantino'], 'synopsis': 'The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.', 'actors': ['John Travolta', 'Uma Thurman', 'Samuel L. Jackson'], 'genre': ['Dark Comedy', 'Drug Crime', 'Gangster', 'Crime', 'Drama'], 'rating': '8.9'}
# 2025-03-25 07:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0110912/?ref_=chttp_t_8>
# {'movie_title': 'Pulp Fiction', 'director': ['Quentin Tarantino'], 'synopsis': 'The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.', 'actors': ['John Travolta', 'Uma Thurman', 'Samuel L. Jackson'], 'genre': ['Dark Comedy', 'Drug Crime', 'Gangster', 'Crime', 'Drama'], 'rating': '8.9'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0099685/?ref_=chttp_i_17> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0099685/?ref_=chttp_i_17> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0468569/?ref_=chttp_i_3> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0468569/?ref_=chttp_i_3> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0099685/?ref_=chttp_i_17>
# {'movie_title': 'Goodfellas', 'director': ['Martin Scorsese'], 'synopsis': 'The story of Henry Hill and his life in the mafia, covering his relationship with his wife Karen and his mob partners Jimmy Conway and Tommy DeVito.', 'actors': ['Robert De Niro', 'Joe Pesci', 'Ray Liotta'], 'genre': ['Docudrama', 'Gangster', 'True Crime', 'Biography', 'Crime', 'Drama'], 'rating': '8.7'}
# 2025-03-25 07:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0099685/?ref_=chttp_i_17>
# {'movie_title': 'Goodfellas', 'director': ['Martin Scorsese'], 'synopsis': 'The story of Henry Hill and his life in the mafia, covering his relationship with his wife Karen and his mob partners Jimmy Conway and Tommy DeVito.', 'actors': ['Robert De Niro', 'Joe Pesci', 'Ray Liotta'], 'genre': ['Docudrama', 'Gangster', 'True Crime', 'Biography', 'Crime', 'Drama'], 'rating': '8.7'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0468569/?ref_=chttp_i_3>
# {'movie_title': 'The Dark Knight', 'director': ['Christopher Nolan'], 'synopsis': 'When a menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman, James Gordon and Harvey Dent must work together to put an end to the madness.', 'actors': ['Christian Bale', 'Aaron Eckhart', 'Heath Ledger'], 'genre': ['Action Epic', 'Epic', 'Superhero', 'Tragedy', 'Action', 'Crime', 'Drama', 'Thriller'], 'rating': '9.0'}
# 2025-03-25 07:21:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0468569/?ref_=chttp_i_3>
# {'movie_title': 'The Dark Knight', 'director': ['Christopher Nolan'], 'synopsis': 'When a menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman, James Gordon and Harvey Dent must work together to put an end to the madness.', 'actors': ['Christian Bale', 'Aaron Eckhart', 'Heath Ledger'], 'genre': ['Action Epic', 'Epic', 'Superhero', 'Tragedy', 'Action', 'Crime', 'Drama', 'Thriller'], 'rating': '9.0'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0317248/?ref_=chttp_i_25> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0317248/?ref_=chttp_i_25> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0317248/?ref_=chttp_i_25>
# {'movie_title': 'City of God', 'director': ['Kátia Lund', 'Fernando Meirelles'], 'synopsis': "In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.", 'actors': ['Alexandre Rodrigues', 'Matheus Nachtergaele', 'Leandro Firmino'], 'genre': ['Caper', 'Coming-of-Age', 'Gangster', 'Crime', 'Drama'], 'rating': '8.6'}
# 2025-03-25 07:21:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0317248/?ref_=chttp_i_25>
# {'movie_title': 'City of God', 'director': ['Kátia Lund', 'Fernando Meirelles'], 'synopsis': "In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.", 'actors': ['Alexandre Rodrigues', 'Matheus Nachtergaele', 'Leandro Firmino'], 'genre': ['Caper', 'Coming-of-Age', 'Gangster', 'Crime', 'Drama'], 'rating': '8.6'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0080684/?ref_=chttp_t_15> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0080684/?ref_=chttp_t_15> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0080684/?ref_=chttp_i_15> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0080684/?ref_=chttp_i_15> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0071562/?ref_=chttp_t_4> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0071562/?ref_=chttp_t_4> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0080684/?ref_=chttp_t_15>
# {'movie_title': 'Star Wars: Episode V - The Empire Strikes Back', 'director': ['Irvin Kershner'], 'synopsis': 'After the Empire overpowers the Rebel Alliance, Luke Skywalker begins training with Jedi Master Yoda, while Darth Vader and bounty hunter Boba Fett pursue his friends across the galaxy.', 'actors': ['Harrison Ford', 'Mark Hamill', 'Carrie Fisher'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Globetrotting Adventure', 'Quest', 'Sci-Fi Epic', 'Space Sci-Fi', 'Sword & Sorcery'], 'rating': '8.7'}
# 2025-03-25 07:21:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0080684/?ref_=chttp_t_15>
# {'movie_title': 'Star Wars: Episode V - The Empire Strikes Back', 'director': ['Irvin Kershner'], 'synopsis': 'After the Empire overpowers the Rebel Alliance, Luke Skywalker begins training with Jedi Master Yoda, while Darth Vader and bounty hunter Boba Fett pursue his friends across the galaxy.', 'actors': ['Harrison Ford', 'Mark Hamill', 'Carrie Fisher'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Globetrotting Adventure', 'Quest', 'Sci-Fi Epic', 'Space Sci-Fi', 'Sword & Sorcery'], 'rating': '8.7'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0080684/?ref_=chttp_i_15>
# {'movie_title': 'Star Wars: Episode V - The Empire Strikes Back', 'director': ['Irvin Kershner'], 'synopsis': 'After the Empire overpowers the Rebel Alliance, Luke Skywalker begins training with Jedi Master Yoda, while Darth Vader and bounty hunter Boba Fett pursue his friends across the galaxy.', 'actors': ['Harrison Ford', 'Mark Hamill', 'Carrie Fisher'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Globetrotting Adventure', 'Quest', 'Sci-Fi Epic', 'Space Sci-Fi', 'Sword & Sorcery'], 'rating': '8.7'}
# 2025-03-25 07:21:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0080684/?ref_=chttp_i_15>
# {'movie_title': 'Star Wars: Episode V - The Empire Strikes Back', 'director': ['Irvin Kershner'], 'synopsis': 'After the Empire overpowers the Rebel Alliance, Luke Skywalker begins training with Jedi Master Yoda, while Darth Vader and bounty hunter Boba Fett pursue his friends across the galaxy.', 'actors': ['Harrison Ford', 'Mark Hamill', 'Carrie Fisher'], 'genre': ['Action Epic', 'Adventure Epic', 'Dark Fantasy', 'Epic', 'Fantasy Epic', 'Globetrotting Adventure', 'Quest', 'Sci-Fi Epic', 'Space Sci-Fi', 'Sword & Sorcery'], 'rating': '8.7'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0071562/?ref_=chttp_t_4>
# {'movie_title': 'The Godfather Part II', 'director': ['Francis Ford Coppola'], 'synopsis': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'actors': ['Al Pacino', 'Robert De Niro', 'Robert Duvall'], 'genre': ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama'], 'rating': '9.0'}
# 2025-03-25 07:21:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0071562/?ref_=chttp_t_4>
# {'movie_title': 'The Godfather Part II', 'director': ['Francis Ford Coppola'], 'synopsis': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'actors': ['Al Pacino', 'Robert De Niro', 'Robert Duvall'], 'genre': ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama'], 'rating': '9.0'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0816692/?ref_=chttp_i_19> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0816692/?ref_=chttp_i_19> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0816692/?ref_=chttp_i_19>
# {'movie_title': 'Interstellar', 'director': ['Christopher Nolan'], 'synopsis': 'When Earth becomes uninhabitable in the future, a farmer and ex-NASA pilot, Joseph Cooper, is tasked to pilot a spacecraft, along with a team of researchers, to find a new planet for humans.', 'actors': ['Anne Hathaway', 'Matthew McConaughey', 'Jessica Chastain'], 'genre': ['Adventure Epic', 'Epic', 'Quest', 'Sci-Fi Epic', 'Space Sci-Fi', 'Time Travel', 'Adventure', 'Drama', 'Sci-Fi'], 'rating': '8.7'}
# 2025-03-25 07:21:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0816692/?ref_=chttp_i_19>
# {'movie_title': 'Interstellar', 'director': ['Christopher Nolan'], 'synopsis': 'When Earth becomes uninhabitable in the future, a farmer and ex-NASA pilot, Joseph Cooper, is tasked to pilot a spacecraft, along with a team of researchers, to find a new planet for humans.', 'actors': ['Anne Hathaway', 'Matthew McConaughey', 'Jessica Chastain'], 'genre': ['Adventure Epic', 'Epic', 'Quest', 'Sci-Fi Epic', 'Space Sci-Fi', 'Time Travel', 'Adventure', 'Drama', 'Sci-Fi'], 'rating': '8.7'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0102926/?ref_=chttp_t_23> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0102926/?ref_=chttp_t_23> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0102926/?ref_=chttp_i_23> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0102926/?ref_=chttp_i_23> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0102926/?ref_=chttp_t_23>
# {'movie_title': 'The Silence of the Lambs', 'director': ['Jonathan Demme'], 'synopsis': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.', 'actors': ['Anthony Hopkins', 'Jodie Foster', 'Scott Glenn'], 'genre': ['Police Procedural', 'Psychological Drama', 'Psychological Horror', 'Psychological Thriller', 'Serial Killer', 'Slasher Horror', 'Crime', 'Drama', 'Horror', 'Thriller'], 'rating': '8.6'}
# 2025-03-25 07:21:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0102926/?ref_=chttp_t_23>
# {'movie_title': 'The Silence of the Lambs', 'director': ['Jonathan Demme'], 'synopsis': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.', 'actors': ['Anthony Hopkins', 'Jodie Foster', 'Scott Glenn'], 'genre': ['Police Procedural', 'Psychological Drama', 'Psychological Horror', 'Psychological Thriller', 'Serial Killer', 'Slasher Horror', 'Crime', 'Drama', 'Horror', 'Thriller'], 'rating': '8.6'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0114369/?ref_=chttp_i_20> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0114369/?ref_=chttp_i_20> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0102926/?ref_=chttp_i_23>
# {'movie_title': 'The Silence of the Lambs', 'director': ['Jonathan Demme'], 'synopsis': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.', 'actors': ['Anthony Hopkins', 'Jodie Foster', 'Scott Glenn'], 'genre': ['Police Procedural', 'Psychological Drama', 'Psychological Horror', 'Psychological Thriller', 'Serial Killer', 'Slasher Horror', 'Crime', 'Drama', 'Horror', 'Thriller'], 'rating': '8.6'}
# 2025-03-25 07:21:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0102926/?ref_=chttp_i_23>
# {'movie_title': 'The Silence of the Lambs', 'director': ['Jonathan Demme'], 'synopsis': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.', 'actors': ['Anthony Hopkins', 'Jodie Foster', 'Scott Glenn'], 'genre': ['Police Procedural', 'Psychological Drama', 'Psychological Horror', 'Psychological Thriller', 'Serial Killer', 'Slasher Horror', 'Crime', 'Drama', 'Horror', 'Thriller'], 'rating': '8.6'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0114369/?ref_=chttp_i_20>
# {'movie_title': 'Se7en', 'director': ['David Fincher'], 'synopsis': 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.', 'actors': ['Kevin Spacey', 'Brad Pitt', 'Morgan Freeman'], 'genre': ['Cop Drama', 'Hard-boiled Detective', 'Legal Drama', 'Police Procedural', 'Psychological Drama', 'Psychological Thriller', 'Serial Killer', 'Crime', 'Drama', 'Mystery'], 'rating': '8.6'}
# 2025-03-25 07:21:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0114369/?ref_=chttp_i_20>
# {'movie_title': 'Se7en', 'director': ['David Fincher'], 'synopsis': 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.', 'actors': ['Kevin Spacey', 'Brad Pitt', 'Morgan Freeman'], 'genre': ['Cop Drama', 'Hard-boiled Detective', 'Legal Drama', 'Police Procedural', 'Psychological Drama', 'Psychological Thriller', 'Serial Killer', 'Crime', 'Drama', 'Mystery'], 'rating': '8.6'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0109830/?ref_=chttp_t_11> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0109830/?ref_=chttp_t_11> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0073486/?ref_=chttp_i_18> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0073486/?ref_=chttp_i_18> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0120815/?ref_=chttp_t_24> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0120815/?ref_=chttp_t_24> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0109830/?ref_=chttp_i_11> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0109830/?ref_=chttp_i_11> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0109830/?ref_=chttp_t_11>
# {'movie_title': 'Forrest Gump', 'director': ['Robert Zemeckis'], 'synopsis': "The history of the United States from the 1950s to the '70s unfolds from the perspective of an Alabama man with an IQ of 75, who yearns to be reunited with his childhood sweetheart.", 'actors': ['Robin Wright', 'Gary Sinise', 'Tom Hanks'], 'genre': ['Epic', 'Drama', 'Romance'], 'rating': '8.8'}
# 2025-03-25 07:21:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0109830/?ref_=chttp_t_11>
# {'movie_title': 'Forrest Gump', 'director': ['Robert Zemeckis'], 'synopsis': "The history of the United States from the 1950s to the '70s unfolds from the perspective of an Alabama man with an IQ of 75, who yearns to be reunited with his childhood sweetheart.", 'actors': ['Robin Wright', 'Gary Sinise', 'Tom Hanks'], 'genre': ['Epic', 'Drama', 'Romance'], 'rating': '8.8'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0073486/?ref_=chttp_i_18>
# {'movie_title': "One Flew Over the Cuckoo's Nest", 'director': ['Milos Forman'], 'synopsis': 'In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.', 'actors': ['Louise Fletcher', 'Michael Berryman', 'Jack Nicholson'], 'genre': ['Medical Drama', 'Psychological Drama', 'Drama'], 'rating': '8.7'}
# 2025-03-25 07:21:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0073486/?ref_=chttp_i_18>
# {'movie_title': "One Flew Over the Cuckoo's Nest", 'director': ['Milos Forman'], 'synopsis': 'In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.', 'actors': ['Louise Fletcher', 'Michael Berryman', 'Jack Nicholson'], 'genre': ['Medical Drama', 'Psychological Drama', 'Drama'], 'rating': '8.7'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0120815/?ref_=chttp_t_24>
# {'movie_title': 'Saving Private Ryan', 'director': ['Steven Spielberg'], 'synopsis': 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.', 'actors': ['Tom Sizemore', 'Matt Damon', 'Tom Hanks'], 'genre': ['Epic', 'Period Drama', 'War Epic', 'Drama', 'War'], 'rating': '8.6'}
# 2025-03-25 07:21:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0120815/?ref_=chttp_t_24>
# {'movie_title': 'Saving Private Ryan', 'director': ['Steven Spielberg'], 'synopsis': 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.', 'actors': ['Tom Sizemore', 'Matt Damon', 'Tom Hanks'], 'genre': ['Epic', 'Period Drama', 'War Epic', 'Drama', 'War'], 'rating': '8.6'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0109830/?ref_=chttp_i_11>
# {'movie_title': 'Forrest Gump', 'director': ['Robert Zemeckis'], 'synopsis': "The history of the United States from the 1950s to the '70s unfolds from the perspective of an Alabama man with an IQ of 75, who yearns to be reunited with his childhood sweetheart.", 'actors': ['Robin Wright', 'Gary Sinise', 'Tom Hanks'], 'genre': ['Epic', 'Drama', 'Romance'], 'rating': '8.8'}
# 2025-03-25 07:21:39 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0109830/?ref_=chttp_i_11>
# {'movie_title': 'Forrest Gump', 'director': ['Robert Zemeckis'], 'synopsis': "The history of the United States from the 1950s to the '70s unfolds from the perspective of an Alabama man with an IQ of 75, who yearns to be reunited with his childhood sweetheart.", 'actors': ['Robin Wright', 'Gary Sinise', 'Tom Hanks'], 'genre': ['Epic', 'Drama', 'Romance'], 'rating': '8.8'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0050083/?ref_=chttp_t_5> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0050083/?ref_=chttp_t_5> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt1375666/?ref_=chttp_i_14> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt1375666/?ref_=chttp_i_14> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0050083/?ref_=chttp_t_5>
# {'movie_title': '12 Angry Men', 'director': ['Sidney Lumet'], 'synopsis': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.', 'actors': ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam'], 'genre': ['Legal Drama', 'Psychological Drama', 'Crime', 'Drama'], 'rating': '9.0'}
# 2025-03-25 07:21:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0050083/?ref_=chttp_t_5>
# {'movie_title': '12 Angry Men', 'director': ['Sidney Lumet'], 'synopsis': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.', 'actors': ['Henry Fonda', 'Lee J. Cobb', 'Martin Balsam'], 'genre': ['Legal Drama', 'Psychological Drama', 'Crime', 'Drama'], 'rating': '9.0'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt1375666/?ref_=chttp_i_14>
# {'movie_title': 'Inception', 'director': ['Christopher Nolan'], 'synopsis': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the pro...', 'actors': ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Elliot Page'], 'genre': ['Action Epic', 'Adventure Epic', 'Epic', 'Psychological Thriller', 'Sci-Fi Epic', 'Action', 'Adventure', 'Sci-Fi', 'Thriller'], 'rating': '8.8'}
# 2025-03-25 07:21:40 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt1375666/?ref_=chttp_i_14>
# ...
# 2025-03-25 07:21:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0167260/?ref_=chttp_i_6>
# {'movie_title': 'The Lord of the Rings: The Return of the King', 'director': ['Peter Jackson'], 'synopsis': "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.", 'actors': ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen'], 'genre': ['Action Epic', 'Adventure Epic', 'Epic', 'Fantasy Epic', 'Mountain Adventure', 'Quest', 'Sword & Sorcery', 'Tragedy', 'Adventure', 'Drama'], 'rating': '9.0'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0071562/?ref_=chttp_i_4>
# {'movie_title': 'The Godfather Part II', 'director': ['Francis Ford Coppola'], 'synopsis': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'actors': ['Al Pacino', 'Robert De Niro', 'Robert Duvall'], 'genre': ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama'], 'rating': '9.0'}
# 2025-03-25 07:21:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0071562/?ref_=chttp_i_4>
# {'movie_title': 'The Godfather Part II', 'director': ['Francis Ford Coppola'], 'synopsis': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.', 'actors': ['Al Pacino', 'Robert De Niro', 'Robert Duvall'], 'genre': ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama'], 'rating': '9.0'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0133093/?ref_=chttp_i_16> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0133093/?ref_=chttp_i_16> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt1375666/?ref_=chttp_t_14> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt1375666/?ref_=chttp_t_14> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0060196/?ref_=chttp_t_10> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0060196/?ref_=chttp_t_10> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0133093/?ref_=chttp_i_16>
# {'movie_title': 'The Matrix', 'director': ['Lana Wachowski', 'Lilly Wachowski'], 'synopsis': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.', 'actors': ['Laurence Fishburne', 'Keanu Reeves', 'Carrie-Anne Moss'], 'genre': ['Action Epic', 'Artificial Intelligence', 'Cyberpunk', 'Dystopian Sci-Fi', 'Gun Fu', 'Martial Arts', 'Sci-Fi Epic', 'Action', 'Sci-Fi'], 'rating': '8.7'}
# 2025-03-25 07:21:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0133093/?ref_=chttp_i_16>
# {'movie_title': 'The Matrix', 'director': ['Lana Wachowski', 'Lilly Wachowski'], 'synopsis': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.', 'actors': ['Laurence Fishburne', 'Keanu Reeves', 'Carrie-Anne Moss'], 'genre': ['Action Epic', 'Artificial Intelligence', 'Cyberpunk', 'Dystopian Sci-Fi', 'Gun Fu', 'Martial Arts', 'Sci-Fi Epic', 'Action', 'Sci-Fi'], 'rating': '8.7'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt1375666/?ref_=chttp_t_14>
# {'movie_title': 'Inception', 'director': ['Christopher Nolan'], 'synopsis': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the pro...', 'actors': ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Elliot Page'], 'genre': ['Action Epic', 'Adventure Epic', 'Epic', 'Psychological Thriller', 'Sci-Fi Epic', 'Action', 'Adventure', 'Sci-Fi', 'Thriller'], 'rating': '8.8'}
# 2025-03-25 07:21:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt1375666/?ref_=chttp_t_14>
# {'movie_title': 'Inception', 'director': ['Christopher Nolan'], 'synopsis': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the pro...', 'actors': ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', 'Elliot Page'], 'genre': ['Action Epic', 'Adventure Epic', 'Epic', 'Psychological Thriller', 'Sci-Fi Epic', 'Action', 'Adventure', 'Sci-Fi', 'Thriller'], 'rating': '8.8'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0060196/?ref_=chttp_t_10>
# {'movie_title': 'The Good, the Bad and the Ugly', 'director': ['Sergio Leone'], 'synopsis': 'A bounty-hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.', 'actors': ['Lee Van Cleef', 'Eli Wallach', 'Clint Eastwood'], 'genre': ['Adventure Epic', 'Dark Comedy', 'Desert Adventure', 'Epic', 'Period Drama', 'Quest', 'Spaghetti Western', 'Western Epic', 'Adventure', 'Western'], 'rating': '8.8'}
# 2025-03-25 07:21:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0060196/?ref_=chttp_t_10>
# {'movie_title': 'The Good, the Bad and the Ugly', 'director': ['Sergio Leone'], 'synopsis': 'A bounty-hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.', 'actors': ['Lee Van Cleef', 'Eli Wallach', 'Clint Eastwood'], 'genre': ['Adventure Epic', 'Dark Comedy', 'Desert Adventure', 'Epic', 'Period Drama', 'Quest', 'Spaghetti Western', 'Western Epic', 'Adventure', 'Western'], 'rating': '8.8'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0120815/?ref_=chttp_i_24> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0120815/?ref_=chttp_i_24> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0111161/?ref_=chttp_t_1> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0111161/?ref_=chttp_t_1> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0120815/?ref_=chttp_i_24>
# {'movie_title': 'Saving Private Ryan', 'director': ['Steven Spielberg'], 'synopsis': 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.', 'actors': ['Tom Sizemore', 'Matt Damon', 'Tom Hanks'], 'genre': ['Epic', 'Period Drama', 'War Epic', 'Drama', 'War'], 'rating': '8.6'}
# 2025-03-25 07:21:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0120815/?ref_=chttp_i_24>
# {'movie_title': 'Saving Private Ryan', 'director': ['Steven Spielberg'], 'synopsis': 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.', 'actors': ['Tom Sizemore', 'Matt Damon', 'Tom Hanks'], 'genre': ['Epic', 'Period Drama', 'War Epic', 'Drama', 'War'], 'rating': '8.6'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0111161/?ref_=chttp_t_1>
# {'movie_title': 'The Shawshank Redemption', 'director': ['Frank Darabont'], 'synopsis': 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.', 'actors': ['Tim Robbins', 'Bob Gunton', 'Morgan Freeman'], 'genre': ['Epic', 'Period Drama', 'Prison Drama', 'Drama'], 'rating': '9.3'}
# 2025-03-25 07:21:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0111161/?ref_=chttp_t_1>
# {'movie_title': 'The Shawshank Redemption', 'director': ['Frank Darabont'], 'synopsis': 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.', 'actors': ['Tim Robbins', 'Bob Gunton', 'Morgan Freeman'], 'genre': ['Epic', 'Period Drama', 'Prison Drama', 'Drama'], 'rating': '9.3'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0167260/?ref_=chttp_t_6> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0167260/?ref_=chttp_t_6> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0167260/?ref_=chttp_t_6>
# {'movie_title': 'The Lord of the Rings: The Return of the King', 'director': ['Peter Jackson'], 'synopsis': "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.", 'actors': ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen'], 'genre': ['Action Epic', 'Adventure Epic', 'Epic', 'Fantasy Epic', 'Mountain Adventure', 'Quest', 'Sword & Sorcery', 'Tragedy', 'Adventure', 'Drama'], 'rating': '9.0'}
# 2025-03-25 07:21:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0167260/?ref_=chttp_t_6>
# {'movie_title': 'The Lord of the Rings: The Return of the King', 'director': ['Peter Jackson'], 'synopsis': "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.", 'actors': ['Elijah Wood', 'Viggo Mortensen', 'Ian McKellen'], 'genre': ['Action Epic', 'Adventure Epic', 'Epic', 'Fantasy Epic', 'Mountain Adventure', 'Quest', 'Sword & Sorcery', 'Tragedy', 'Adventure', 'Drama'], 'rating': '9.0'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0068646/?ref_=chttp_i_2> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0068646/?ref_=chttp_i_2> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0068646/?ref_=chttp_i_2>
# {'movie_title': 'The Godfather', 'director': ['Francis Ford Coppola'], 'synopsis': 'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.', 'actors': ['Al Pacino', 'James Caan', 'Marlon Brando'], 'genre': ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama'], 'rating': '9.2'}
# 2025-03-25 07:21:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0068646/?ref_=chttp_i_2>
# {'movie_title': 'The Godfather', 'director': ['Francis Ford Coppola'], 'synopsis': 'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.', 'actors': ['Al Pacino', 'James Caan', 'Marlon Brando'], 'genre': ['Epic', 'Gangster', 'Tragedy', 'Crime', 'Drama'], 'rating': '9.2'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.imdb.com/title/tt0038650/?ref_=chttp_t_21> (referer: https://www.imdb.com/chart/top/)
# 2025-03-25 07:21:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.imdb.com/title/tt0038650/?ref_=chttp_t_21> (referer: https://www.imdb.com/chart/top/)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.imdb.com/title/tt0038650/?ref_=chttp_t_21>
# {'movie_title': "It's a Wonderful Life", 'director': ['Frank Capra'], 'synopsis': 'An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed.', 'actors': ['Donna Reed', 'Lionel Barrymore', 'James Stewart'], 'genre': ['Feel-Good Romance', 'Holiday Family', 'Holiday Romance', 'Psychological Drama', 'Supernatural Fantasy', 'Drama', 'Family', 'Fantasy', 'Holiday', 'Romance'], 'rating': '8.6'}
# 2025-03-25 07:21:43 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.imdb.com/title/tt0038650/?ref_=chttp_t_21>
# {'movie_title': "It's a Wonderful Life", 'director': ['Frank Capra'], 'synopsis': 'An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed.', 'actors': ['Donna Reed', 'Lionel Barrymore', 'James Stewart'], 'genre': ['Feel-Good Romance', 'Holiday Family', 'Holiday Romance', 'Psychological Drama', 'Supernatural Fantasy', 'Drama', 'Family', 'Fantasy', 'Holiday', 'Romance'], 'rating': '8.6'}
# INFO:scrapy.core.engine:Closing spider (finished)
# 2025-03-25 07:21:43 [scrapy.core.engine] INFO: Closing spider (finished)
# INFO:scrapy.extensions.feedexport:Stored csv feed (50 items) in: imdb_top250_detailed.csv
# 2025-03-25 07:21:43 [scrapy.extensions.feedexport] INFO: Stored csv feed (50 items) in: imdb_top250_detailed.csv
# INFO:scrapy.statscollectors:Dumping Scrapy stats:
# {'downloader/request_bytes': 35348,
#  'downloader/request_count': 52,
#  'downloader/request_method_count/GET': 52,
#  'downloader/response_bytes': 12442088,
#  'downloader/response_count': 52,
#  'downloader/response_status_count/200': 52,
#  'elapsed_time_seconds': 14.564961,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 3, 25, 7, 21, 43, 887670, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 63776289,
#  'httpcompression/response_count': 51,
#  'item_scraped_count': 50,
#  'items_per_minute': None,
#  'log_count/DEBUG': 104,
#  'log_count/INFO': 11,
#  'memusage/max': 217513984,
#  'memusage/startup': 217513984,
#  'request_depth_max': 1,
#  'response_received_count': 52,
#  'responses_per_minute': None,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 51,
#  'scheduler/dequeued/memory': 51,
#  'scheduler/enqueued': 51,
#  'scheduler/enqueued/memory': 51,
#  'start_time': datetime.datetime(2025, 3, 25, 7, 21, 29, 322709, tzinfo=datetime.timezone.utc)}
# 2025-03-25 07:21:43 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 35348,
#  'downloader/request_count': 52,
#  'downloader/request_method_count/GET': 52,
#  'downloader/response_bytes': 12442088,
#  'downloader/response_count': 52,
#  'downloader/response_status_count/200': 52,
#  'elapsed_time_seconds': 14.564961,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 3, 25, 7, 21, 43, 887670, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 63776289,
#  'httpcompression/response_count': 51,
#  'item_scraped_count': 50,
#  'items_per_minute': None,
#  'log_count/DEBUG': 104,
#  'log_count/INFO': 11,
#  'memusage/max': 217513984,
#  'memusage/startup': 217513984,
#  'request_depth_max': 1,
#  'response_received_count': 52,
#  'responses_per_minute': None,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 51,
#  'scheduler/dequeued/memory': 51,
#  'scheduler/enqueued': 51,
#  'scheduler/enqueued/memory': 51,
#  'start_time': datetime.datetime(2025, 3, 25, 7, 21, 29, 322709, tzinfo=datetime.timezone.utc)}
# INFO:scrapy.core.engine:Spider closed (finished)
# 2025-03-25 07:21:43 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Save the CSV file to Google Drive

# %%
import os
import shutil
from google.colab import drive

drive.mount('/content/drive')

imdb_folder_path = '/content/drive/MyDrive/imdb'

# Create the 'imdb' folder if it doesn't exist
if not os.path.exists(imdb_folder_path):
    os.makedirs(imdb_folder_path)

# Copy the CSV file to the 'imdb' folder
shutil.copy('/content/imdb_top250_detailed.csv', imdb_folder_path)
# Out:
# Mounted at /content/drive
# '/content/drive/MyDrive/imdb/imdb_top250_detailed.csv'

# %% [markdown]
# The CSV file contains duplicates, commas, and square brackets in some values. Data needs to be cleaned using OpenRefine or Excel before using further for converting into RDF or some other use case.
